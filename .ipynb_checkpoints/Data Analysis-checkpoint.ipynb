# %%
import seaborn as sn
import pandas as pd
import mysql.connector
import numpy as np
import matplotlib.pyplot as plt

# %%
df =pd.DataFrame([], columns = ['Date','Count'])

# %%
mydb = mysql.connector.connect(
  host="localhost",
  user='root',
  password='root',
  database="dmdw"
)

# %%
#mycursor = mydb.cursor()
#mycursor.execute("select distinct(date_format(date(issu_date),'%y/%m/%d')),count(*) from ticket where year(issu_date)=2022 and month(issu_date) = 7 group by date(issu_date) order by issu_date asc limit 31")
#myresult = mycursor.fetchall()

# %%
mycursor = mydb.cursor()
mycursor.execute("""
select distinct(date_format(date(issu_date),'%y/%m/%d %h')),count(*) from 
ticket where year(issu_date) = 2022 and month(issu_date) > 4 group by date_format(date(issu_date),'%y/%m/%d %h');""")
myresult = mycursor.fetchall()

# %%
#mycursor = mydb.cursor()
#mycursor.execute("select distinct(date_format(date(issu_date),'%y/%m/%d')),count(*) from ticket group by date_format(date(issu_date),'%y/%m/%d') order by date_format(date(issu_date),'%y/%m/%d') asc")
#myresult = mycursor.fetchall()

# %%
def add_to_data(arr):
    df.loc[len(df)] = arr

# %%
for i in range(0,len(myresult)):
    add_to_data(np.asarray(myresult[i]))

# %%
#df['Date'] = pd.to_datetime(df['Date'])
df["Date"] = df["Date"].astype("str") 
df['Count'] = df['Count'].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 104 entries, 0 to 103
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    104 non-null    object
#  1   Count   104 non-null    int32
# dtypes: int32(1), object(1)
# memory usage: 2.0+ KB

# %%
df = df[df['Count']>1000]

# %%
a = sn.lineplot(data=df, x='Date', y='Count')
a.tick_params(axis='x', rotation=90)

# %%
mycursor = mydb.cursor()
mycursor.execute(""" select DATE_FORMAT(issu_date, '%y/%m/%d'),hour(issu_date), count(*) from ticket where year(issu_date) = 2022 and month(issu_date) >5 group by date(issu_date),hour(issu_date) 
""")
myresult = mycursor.fetchall()

# %%
for i in range(0,20):
    if len(str(myresult[i][1])) >= 7:
        time = "0" + str(myresult[i][1])
    else :
        time = str(myresult[i][1])
    print([str(myresult[i][0]) + " " +time+":00:00",myresult[i][2]])
# Out:
# ['22/06/01 0:00:00', 4]
# ['22/06/01 1:00:00', 3]
# ['22/06/01 2:00:00', 4]
# ['22/06/01 3:00:00', 1]
# ['22/06/01 4:00:00', 2]
# ['22/06/01 5:00:00', 2]
# ['22/06/01 6:00:00', 2]
# ['22/06/01 7:00:00', 1]
# ['22/06/01 8:00:00', 4]
# ['22/06/01 9:00:00', 4]
# ['22/06/01 10:00:00', 2]
# ['22/06/01 11:00:00', 9]
# ['22/06/01 12:00:00', 2]
# ['22/06/01 13:00:00', 2]
# ['22/06/01 14:00:00', 2]
# ['22/06/01 19:00:00', 2]
# ['22/06/01 22:00:00', 4]
# ['22/06/01 23:00:00', 1]
# ['22/06/02 0:00:00', 2]
# ['22/06/02 1:00:00', 1]

# %%
df =pd.DataFrame([], columns = ['Date','Count'])

# %%
for i in range(0,len(myresult)):
    df.loc[len(df)] = np.asarray([str(myresult[i][0]) + " " +str(myresult[i][1])+":00:00",myresult[i][2]])

# %%
df["Date"] = df["Date"].astype("str") 
df['Count'] = df['Count'].astype(int)

# %%
df = df[df['Count']>50]

# %%
sn.set(rc={"figure.figsize":(16*5, 8*5)})
a = sn.lineplot(data=df, x='Date', y='Count')
a.tick_params(axis='x', rotation=90)
